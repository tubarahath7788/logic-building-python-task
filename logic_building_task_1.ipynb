# %%
username = "admin"
password = "1234"

input_username = "admin"
input_password = "1234"

if input_username == username and input_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Login Successful

# %% [markdown]
# Task 1: User Login Check
#
#  Real-World Application:
#
# Authentication systems
#
#  Logic Explanation:
#
# Compare input username and password with stored values
#
# If both match → login successful
#
# Else → invalid credentials

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Pass Students:", pass_count)
print("Total Fail Students:", fail_count)
# Out:
# Total Pass Students: 3
# Total Fail Students: 2

# %% [markdown]
# Task 2: Pass / Fail Analyzer
#
#
#
#
# Real-World Application:
#
# Academic evaluation systems
#
# Logic Explanation:
#
# Students pass if marks ≥ 50
#
# Iterate through marks
#
# Count pass and fail

# %%
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    cleaned_names.append(name.strip().lower())

print("Cleaned Names:", cleaned_names)
# Out:
# Cleaned Names: ['alice', 'bob', 'charlie']

# %% [markdown]
# Task 3: Simple Data Cleaner
#
#
# Real-World Application:
#
# Data preprocessing before analysis
#
# Logic Explanation:
#
# Remove leading and trailing spaces
#
# Convert names to lowercase

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print(f"Message: '{message}' | Length: {length}")

    if length > 10:
        print("⚠️ This message is longer than 10 characters")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# ⚠️ This message is longer than 10 characters
# Message: 'OK' | Length: 2

# %% [markdown]
# Task 4: Message Length Analyzer
#
#
#  Real-World Application:
#
# Text filtering and validation systems
#
# Logic Explanation:
#
# Calculate length of each message
#
# Flag messages longer than 10 characters

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("Total ERROR messages:", error_count)
# Out:
# Total ERROR messages: 2

# %% [markdown]
# Task 5: Error Message Detector
#
# Real-World Application:
#
# Monitoring and log analysis systems
#
# Logic Explanation:
#
# Count occurrences of "ERROR"
#
# Display total error count

# %% [markdown]
# Conclusion:
#
# This notebook demonstrates basic Python logic-building skills such as:
#
# Conditional statements
#
# Loops
#
# String handling
#
# Data validation
#
# These concepts are fundamental for real-world software and data-related applications.
